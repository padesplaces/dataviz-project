# %%
import pandas as pd
import numpy as np
import pickle
import glob
import matplotlib.pyplot as plt
import json
from tqdm import tqdm_notebook
import os

# %%
full_df = pd.concat([pd.read_csv(f, compression='gzip') for f in glob.glob("../data/full-data/*.gzip")], ignore_index=True)
full_df
# Out:
#          GLOBALEVENTID    MentionSourceName  \
# 0            714712065              npr.org
# 1            714694876              npr.org
# 2            714914448              npr.org
# 3            714914794              npr.org
# 4            714913892              npr.org
# 5            714694328              npr.org
# 6            721613923              npr.org
# 7            771525591              npr.org
# 8            771526954              npr.org
# 9            733479049              npr.org
# 10           711707599              npr.org
# 11           747225017              npr.org
# 12           754289773              npr.org
# 13           754290222              npr.org
# 14           754291448              npr.org
# 15           754290238              npr.org
# 16           754291660              npr.org
# 17           739164524              npr.org
# 18           747675124              npr.org
# 19           714691455              npr.org
# 20           726738245              npr.org
# 21           726740136              npr.org
# 22           726738239              npr.org
# 23           757185377              npr.org
# 24           716064842              npr.org
# 25           718375652              npr.org
# 26           718376564              npr.org
# 27           720862135              npr.org
# 28           720862452              npr.org
# 29           720862403              npr.org
# ...                ...                  ...
# 5912860      799589200  nbcphiladelphia.com
# 5912861      799637459  nbcphiladelphia.com
# 5912862      771931709  nbcphiladelphia.com
# 5912863      793702631  nbcphiladelphia.com
# 5912864      733920354  nbcphiladelphia.com
# 5912865      733919237  nbcphiladelphia.com
# 5912866      735693014  nbcphiladelphia.com
# 5912867      735693015  nbcphiladelphia.com
# 5912868      770230587  nbcphiladelphia.com
# 5912869      801199526  nbcphiladelphia.com
# 5912870      765283545  nbcphiladelphia.com
# 5912871      765526496  nbcphiladelphia.com
# 5912872      781058392  nbcphiladelphia.com
# 5912873      781057033  nbcphiladelphia.com
# 5912874      781040591  nbcphiladelphia.com
# 5912875      805760585  nbcphiladelphia.com
# 5912876      779866806  nbcphiladelphia.com
# 5912877      779868563  nbcphiladelphia.com
# 5912878      776377158  nbcphiladelphia.com
# 5912879      734295857  nbcphiladelphia.com
# 5912880      734197049  nbcphiladelphia.com
# 5912881      734234815  nbcphiladelphia.com
# 5912882      734197095  nbcphiladelphia.com
# 5912883      766305556  nbcphiladelphia.com
# 5912884      766304604  nbcphiladelphia.com
# 5912885      799659647  nbcphiladelphia.com
# 5912886      805787042  nbcphiladelphia.com
# 5912887      805575749  nbcphiladelphia.com
# 5912888      805761251  nbcphiladelphia.com
# 5912889      805761026  nbcphiladelphia.com
#
#                                         DocumentIdentifier            DATE  \
# 0             https://www.npr.org/podcasts/510318/up-first  20171213163000
# 1             https://www.npr.org/podcasts/510318/up-first  20171213163000
# 2             https://www.npr.org/podcasts/510318/up-first  20171213163000
# 3             https://www.npr.org/podcasts/510318/up-first  20171213163000
# 4             https://www.npr.org/podcasts/510318/up-first  20171213163000
# 5             https://www.npr.org/podcasts/510318/up-first  20171213163000
# 6         https://www.npr.org/series/473636949/schoolmoney  20180111203000
# 7        https://www.npr.org/podcasts/381444767/u-w-m-t...  20180712174500
# 8        https://www.npr.org/podcasts/381444767/u-w-m-t...  20180712174500
# 9        https://www.npr.org/series/347174484/jazz-nigh...  20180223211500
# 10       https://www.npr.org/2017/10/12/557356911/enter...  20171202184500
# 11       https://www.npr.org/2018/04/13/601971617/the-c...  20180413121500
# 12       https://www.npr.org/podcasts/605235114/idaho-m...  20180509041500
# 13       https://www.npr.org/podcasts/605235114/idaho-m...  20180509041500
# 14       https://www.npr.org/podcasts/605235114/idaho-m...  20180509041500
# 15       https://www.npr.org/podcasts/605235114/idaho-m...  20180509041500
# 16       https://www.npr.org/podcasts/605235114/idaho-m...  20180509041500
# 17       https://www.npr.org/series/347174538/jazz-nigh...  20180316143000
# 18       https://www.npr.org/2018/04/14/602443800/view-...  20180415161500
# 19       https://www.npr.org/podcasts/510310/npr-politi...  20171214033000
# 20       https://www.npr.org/templates/corrections/corr...  20180130174500
# 21       https://www.npr.org/templates/corrections/corr...  20180130174500
# 22       https://www.npr.org/templates/corrections/corr...  20180130174500
# 23       https://www.npr.org/2018/05/18/612156090/the-e...  20180518161500
# 24       https://www.npr.org/2017/12/18/571579606/morni...  20171218104500
# 25       https://www.npr.org/2017/12/28/573995878/morni...  20171228120000
# 26       https://www.npr.org/2017/12/28/573995878/morni...  20171228120000
# 27       https://www.npr.org/2018/01/09/576669283/morni...  20180109103000
# 28       https://www.npr.org/2018/01/09/576669283/morni...  20180109103000
# 29       https://www.npr.org/2018/01/09/576669283/morni...  20180109103000
# ...                                                    ...             ...
# 5912860  https://www.nbcphiladelphia.com/news/national-...  20181102220000
# 5912861  https://www.nbcphiladelphia.com/news/national-...  20181102220000
# 5912862  https://www.nbcphiladelphia.com/news/local/Sus...  20180714034500
# 5912863  https://www.nbcphiladelphia.com/news/national-...  20181011210000
# 5912864  https://www.nbcphiladelphia.com/news/national-...  20180226004500
# 5912865  https://www.nbcphiladelphia.com/news/national-...  20180226004500
# 5912866  https://www.nbcphiladelphia.com/weather/PHI-WX...  20180304033000
# 5912867  https://www.nbcphiladelphia.com/weather/PHI-WX...  20180304033000
# 5912868  https://www.nbcphiladelphia.com/news/local/5-F...  20180707213000
# 5912869  https://www.nbcphiladelphia.com/news/local/Phi...  20181109040000
# 5912870  https://www.nbcphiladelphia.com/news/local/Del...  20180619200000
# 5912871  https://www.nbcphiladelphia.com/news/local/Del...  20180619200000
# 5912872  https://www.nbcphiladelphia.com/news/national-...  20180822040000
# 5912873  https://www.nbcphiladelphia.com/news/national-...  20180822040000
# 5912874  https://www.nbcphiladelphia.com/news/national-...  20180822040000
# 5912875  https://www.nbcphiladelphia.com/news/politics/...  20181127204500
# 5912876  https://www.nbcphiladelphia.com/news/national-...  20180816163000
# 5912877  https://www.nbcphiladelphia.com/news/national-...  20180816163000
# 5912878  https://www.nbcphiladelphia.com/news/local/Rit...  20180801214500
# 5912879  https://www.nbcphiladelphia.com/news/local/Che...  20180227074500
# 5912880  https://www.nbcphiladelphia.com/news/local/Che...  20180227074500
# 5912881  https://www.nbcphiladelphia.com/news/local/Che...  20180227074500
# 5912882  https://www.nbcphiladelphia.com/news/local/Che...  20180227074500
# 5912883  https://www.nbcphiladelphia.com/news/national-...  20180622084500
# 5912884  https://www.nbcphiladelphia.com/news/national-...  20180622084500
# 5912885  https://www.nbcphiladelphia.com/news/national-...  20181103030000
# 5912886  https://www.nbcphiladelphia.com/news/national-...  20181127204500
# 5912887  https://www.nbcphiladelphia.com/news/national-...  20181127204500
# 5912888  https://www.nbcphiladelphia.com/news/national-...  20181127204500
# 5912889  https://www.nbcphiladelphia.com/news/national-...  20181127204500
#
#                                                     V2Tone
# 0        -1.51745068285281,1.97268588770865,3.490136570...
# 1        -1.51745068285281,1.97268588770865,3.490136570...
# 2        -1.51745068285281,1.97268588770865,3.490136570...
# 3        -1.51745068285281,1.97268588770865,3.490136570...
# 4        -1.51745068285281,1.97268588770865,3.490136570...
# 5        -1.51745068285281,1.97268588770865,3.490136570...
# 6        0,3.18471337579618,3.18471337579618,6.36942675...
# 7        -1.00090991810737,1.45586897179254,2.456778889...
# 8        -1.00090991810737,1.45586897179254,2.456778889...
# 9        1.26742712294043,3.80228136882129,2.5348542458...
# 10       -3.7117903930131,1.52838427947598,5.2401746724...
# 11       -7.69230769230769,5.38461538461539,13.07692307...
# 12       -0.757575757575757,2.27272727272727,3.03030303...
# 13       -0.757575757575757,2.27272727272727,3.03030303...
# 14       -0.757575757575757,2.27272727272727,3.03030303...
# 15       -0.757575757575757,2.27272727272727,3.03030303...
# 16       -0.757575757575757,2.27272727272727,3.03030303...
# 17       4.09556313993174,5.5745164960182,1.47895335608...
# 18       -0.880503144654088,2.26415094339623,3.14465408...
# 19       -1.22850122850123,2.12940212940213,3.357903357...
# 20       -2.69996625042187,1.0124873439082,3.7124535943...
# 21       -2.69996625042187,1.0124873439082,3.7124535943...
# 22       -2.69996625042187,1.0124873439082,3.7124535943...
# 23       -5.12820512820513,0,5.12820512820513,5.1282051...
# 24       1.70940170940171,3.41880341880342,1.7094017094...
# 25       -7.14285714285714,1.78571428571429,8.928571428...
# 26       -7.14285714285714,1.78571428571429,8.928571428...
# 27       3.07692307692308,3.07692307692308,0,3.07692307...
# 28       3.07692307692308,3.07692307692308,0,3.07692307...
# 29       3.07692307692308,3.07692307692308,0,3.07692307...
# ...                                                    ...
# 5912860  0.715137067938021,4.41001191895113,3.694874851...
# 5912861  0.715137067938021,4.41001191895113,3.694874851...
# 5912862  -4.39882697947214,1.46627565982405,5.865102639...
# 5912863  -6.25,3.36538461538462,9.61538461538462,12.980...
# 5912864  -2.04081632653061,2.04081632653061,4.081632653...
# 5912865  -2.04081632653061,2.04081632653061,4.081632653...
# 5912866  -6.2111801242236,0.62111801242236,6.8322981366...
# 5912867  -6.2111801242236,0.62111801242236,6.8322981366...
# 5912868  -3.52564102564103,1.28205128205128,4.807692307...
# 5912869  -1.95804195804196,2.0979020979021,4.0559440559...
# 5912870  -1.83727034120735,2.6246719160105,4.4619422572...
# 5912871  -1.83727034120735,2.6246719160105,4.4619422572...
# 5912872  -4.50788880540947,1.50262960180316,6.010518407...
# 5912873  -4.50788880540947,1.50262960180316,6.010518407...
# 5912874  -4.50788880540947,1.50262960180316,6.010518407...
# 5912875  0.121359223300971,2.42718446601942,2.305825242...
# 5912876  1.12359550561798,3.59550561797753,2.4719101123...
# 5912877  1.12359550561798,3.59550561797753,2.4719101123...
# 5912878  -8.21917808219178,1.95694716242661,10.17612524...
# 5912879  -2.80373831775701,3.42679127725857,6.230529595...
# 5912880  -2.80373831775701,3.42679127725857,6.230529595...
# 5912881  -2.80373831775701,3.42679127725857,6.230529595...
# 5912882  -2.80373831775701,3.42679127725857,6.230529595...
# 5912883  -3.63036303630363,1.65016501650165,5.280528052...
# 5912884  -3.63036303630363,1.65016501650165,5.280528052...
# 5912885  -0.478468899521531,2.39234449760766,2.87081339...
# 5912886  0.121359223300971,2.42718446601942,2.305825242...
# 5912887  0.121359223300971,2.42718446601942,2.305825242...
# 5912888  0.121359223300971,2.42718446601942,2.305825242...
# 5912889  0.121359223300971,2.42718446601942,2.305825242...
#
# [5912890 rows x 5 columns]

# %%
sources = full_df["MentionSourceName"].unique()

# %%
full_df["avg_tone"] = full_df.V2Tone.map(lambda l : str(l).split(",")[0]).astype(float)

# %%
full_df["month"] = pd.to_datetime(full_df.DATE, format='%Y%m%d%H%M%S').dt.strftime("%b-%y")

# %%
MONTH_LIST = list(set(full_df["month"].unique())-{'Dec-18'}|{'full_year'})
THEME_LIST = [ "all", "social", "conflict", "env", "health", "eco" ]

# %%
ind = {}
ind['all'] = full_df.index.values
for theme in THEME_LIST[1:]:
    with open("../data/indices/"+theme+".pkl", "rb") as f:
        ind[theme] = pickle.load(f)

# %%
nb_mentions_by_sources = full_df.groupby("MentionSourceName").size()

# %%
theme_ratio_by_source = pd.concat([ full_df.loc[ind[theme]].groupby("MentionSourceName").size() / nb_mentions_by_sources for theme in theme_list ], axis=1)

# %%
theme_count_by_source = pd.concat([ full_df.loc[ind[theme]].groupby("MentionSourceName").size() for theme in theme_list ], axis=1)

# %%
theme_count_by_source.rename(dict(zip(range(len(theme_list)),theme_list)), axis=1, inplace=True)

# %%
idx = pd.MultiIndex.from_product([MONTH_LIST, THEME_LIST[1:]],
                                 names=['Month', 'Theme'])
col = sorted(full_df["MentionSourceName"].unique())

count_histograms = pd.DataFrame('-', idx, col)
tone_histograms = pd.DataFrame('-', idx, col)

# %%
pd.DataFrame('-', idx, col)
# Out:
#                    abc13.com abc7news.com autonews.com boston.com  \
# Month     Theme
# Jan-18    social           -            -            -          -
#           conflict         -            -            -          -
#           env              -            -            -          -
#           health           -            -            -          -
#           eco              -            -            -          -
# Jul-18    social           -            -            -          -
#           conflict         -            -            -          -
#           env              -            -            -          -
#           health           -            -            -          -
#           eco              -            -            -          -
# Mar-18    social           -            -            -          -
#           conflict         -            -            -          -
#           env              -            -            -          -
#           health           -            -            -          -
#           eco              -            -            -          -
# Nov-18    social           -            -            -          -
#           conflict         -            -            -          -
#           env              -            -            -          -
#           health           -            -            -          -
#           eco              -            -            -          -
# May-18    social           -            -            -          -
#           conflict         -            -            -          -
#           env              -            -            -          -
#           health           -            -            -          -
#           eco              -            -            -          -
# Feb-18    social           -            -            -          -
#           conflict         -            -            -          -
#           env              -            -            -          -
#           health           -            -            -          -
#           eco              -            -            -          -
# ...                      ...          ...          ...        ...
# Oct-18    social           -            -            -          -
#           conflict         -            -            -          -
#           env              -            -            -          -
#           health           -            -            -          -
#           eco              -            -            -          -
# Aug-18    social           -            -            -          -
#           conflict         -            -            -          -
#           env              -            -            -          -
#           health           -            -            -          -
#           eco              -            -            -          -
# Apr-18    social           -            -            -          -
#           conflict         -            -            -          -
#           env              -            -            -          -
#           health           -            -            -          -
#           eco              -            -            -          -
# Sep-18    social           -            -            -          -
#           conflict         -            -            -          -
#           env              -            -            -          -
#           health           -            -            -          -
#           eco              -            -            -          -
# Jun-18    social           -            -            -          -
#           conflict         -            -            -          -
#           env              -            -            -          -
#           health           -            -            -          -
#           eco              -            -            -          -
# full_year social           -            -            -          -
#           conflict         -            -            -          -
#           env              -            -            -          -
#           health           -            -            -          -
#           eco              -            -            -          -
#
#                    bostonherald.com breitbart.com cbsnews.com  \
# Month     Theme
# Jan-18    social                  -             -           -
#           conflict                -             -           -
#           env                     -             -           -
#           health                  -             -           -
#           eco                     -             -           -
# Jul-18    social                  -             -           -
#           conflict                -             -           -
#           env                     -             -           -
#           health                  -             -           -
#           eco                     -             -           -
# Mar-18    social                  -             -           -
#           conflict                -             -           -
#           env                     -             -           -
#           health                  -             -           -
#           eco                     -             -           -
# Nov-18    social                  -             -           -
#           conflict                -             -           -
#           env                     -             -           -
#           health                  -             -           -
#           eco                     -             -           -
# May-18    social                  -             -           -
#           conflict                -             -           -
#           env                     -             -           -
#           health                  -             -           -
#           eco                     -             -           -
# Feb-18    social                  -             -           -
#           conflict                -             -           -
#           env                     -             -           -
#           health                  -             -           -
#           eco                     -             -           -
# ...                             ...           ...         ...
# Oct-18    social                  -             -           -
#           conflict                -             -           -
#           env                     -             -           -
#           health                  -             -           -
#           eco                     -             -           -
# Aug-18    social                  -             -           -
#           conflict                -             -           -
#           env                     -             -           -
#           health                  -             -           -
#           eco                     -             -           -
# Apr-18    social                  -             -           -
#           conflict                -             -           -
#           env                     -             -           -
#           health                  -             -           -
#           eco                     -             -           -
# Sep-18    social                  -             -           -
#           conflict                -             -           -
#           env                     -             -           -
#           health                  -             -           -
#           eco                     -             -           -
# Jun-18    social                  -             -           -
#           conflict                -             -           -
#           env                     -             -           -
#           health                  -             -           -
#           eco                     -             -           -
# full_year social                  -             -           -
#           conflict                -             -           -
#           env                     -             -           -
#           health                  -             -           -
#           eco                     -             -           -
#
#                    chicagotribune.com denverpost.com fox2now.com   ...     \
# Month     Theme                                                    ...
# Jan-18    social                    -              -           -   ...
#           conflict                  -              -           -   ...
#           env                       -              -           -   ...
#           health                    -              -           -   ...
#           eco                       -              -           -   ...
# Jul-18    social                    -              -           -   ...
#           conflict                  -              -           -   ...
#           env                       -              -           -   ...
#           health                    -              -           -   ...
#           eco                       -              -           -   ...
# Mar-18    social                    -              -           -   ...
#           conflict                  -              -           -   ...
#           env                       -              -           -   ...
#           health                    -              -           -   ...
#           eco                       -              -           -   ...
# Nov-18    social                    -              -           -   ...
#           conflict                  -              -           -   ...
#           env                       -              -           -   ...
#           health                    -              -           -   ...
#           eco                       -              -           -   ...
# May-18    social                    -              -           -   ...
#           conflict                  -              -           -   ...
#           env                       -              -           -   ...
#           health                    -              -           -   ...
#           eco                       -              -           -   ...
# Feb-18    social                    -              -           -   ...
#           conflict                  -              -           -   ...
#           env                       -              -           -   ...
#           health                    -              -           -   ...
#           eco                       -              -           -   ...
# ...                               ...            ...         ...   ...
# Oct-18    social                    -              -           -   ...
#           conflict                  -              -           -   ...
#           env                       -              -           -   ...
#           health                    -              -           -   ...
#           eco                       -              -           -   ...
# Aug-18    social                    -              -           -   ...
#           conflict                  -              -           -   ...
#           env                       -              -           -   ...
#           health                    -              -           -   ...
#           eco                       -              -           -   ...
# Apr-18    social                    -              -           -   ...
#           conflict                  -              -           -   ...
#           env                       -              -           -   ...
#           health                    -              -           -   ...
#           eco                       -              -           -   ...
# Sep-18    social                    -              -           -   ...
#           conflict                  -              -           -   ...
#           env                       -              -           -   ...
#           health                    -              -           -   ...
#           eco                       -              -           -   ...
# Jun-18    social                    -              -           -   ...
#           conflict                  -              -           -   ...
#           env                       -              -           -   ...
#           health                    -              -           -   ...
#           eco                       -              -           -   ...
# full_year social                    -              -           -   ...
#           conflict                  -              -           -   ...
#           env                       -              -           -   ...
#           health                    -              -           -   ...
#           eco                       -              -           -   ...
#
#                    seattlepi.com seattletimes.com stltoday.com theonion.com  \
# Month     Theme
# Jan-18    social               -                -            -            -
#           conflict             -                -            -            -
#           env                  -                -            -            -
#           health               -                -            -            -
#           eco                  -                -            -            -
# Jul-18    social               -                -            -            -
#           conflict             -                -            -            -
#           env                  -                -            -            -
#           health               -                -            -            -
#           eco                  -                -            -            -
# Mar-18    social               -                -            -            -
#           conflict             -                -            -            -
#           env                  -                -            -            -
#           health               -                -            -            -
#           eco                  -                -            -            -
# Nov-18    social               -                -            -            -
#           conflict             -                -            -            -
#           env                  -                -            -            -
#           health               -                -            -            -
#           eco                  -                -            -            -
# May-18    social               -                -            -            -
#           conflict             -                -            -            -
#           env                  -                -            -            -
#           health               -                -            -            -
#           eco                  -                -            -            -
# Feb-18    social               -                -            -            -
#           conflict             -                -            -            -
#           env                  -                -            -            -
#           health               -                -            -            -
#           eco                  -                -            -            -
# ...                          ...              ...          ...          ...
# Oct-18    social               -                -            -            -
#           conflict             -                -            -            -
#           env                  -                -            -            -
#           health               -                -            -            -
#           eco                  -                -            -            -
# Aug-18    social               -                -            -            -
#           conflict             -                -            -            -
#           env                  -                -            -            -
#           health               -                -            -            -
#           eco                  -                -            -            -
# Apr-18    social               -                -            -            -
#           conflict             -                -            -            -
#           env                  -                -            -            -
#           health               -                -            -            -
#           eco                  -                -            -            -
# Sep-18    social               -                -            -            -
#           conflict             -                -            -            -
#           env                  -                -            -            -
#           health               -                -            -            -
#           eco                  -                -            -            -
# Jun-18    social               -                -            -            -
#           conflict             -                -            -            -
#           env                  -                -            -            -
#           health               -                -            -            -
#           eco                  -                -            -            -
# full_year social               -                -            -            -
#           conflict             -                -            -            -
#           env                  -                -            -            -
#           health               -                -            -            -
#           eco                  -                -            -            -
#
#                    twincities.com usatoday.com villagevoice.com westword.com  \
# Month     Theme
# Jan-18    social                -            -                -            -
#           conflict              -            -                -            -
#           env                   -            -                -            -
#           health                -            -                -            -
#           eco                   -            -                -            -
# Jul-18    social                -            -                -            -
#           conflict              -            -                -            -
#           env                   -            -                -            -
#           health                -            -                -            -
#           eco                   -            -                -            -
# Mar-18    social                -            -                -            -
#           conflict              -            -                -            -
#           env                   -            -                -            -
#           health                -            -                -            -
#           eco                   -            -                -            -
# Nov-18    social                -            -                -            -
#           conflict              -            -                -            -
#           env                   -            -                -            -
#           health                -            -                -            -
#           eco                   -            -                -            -
# May-18    social                -            -                -            -
#           conflict              -            -                -            -
#           env                   -            -                -            -
#           health                -            -                -            -
#           eco                   -            -                -            -
# Feb-18    social                -            -                -            -
#           conflict              -            -                -            -
#           env                   -            -                -            -
#           health                -            -                -            -
#           eco                   -            -                -            -
# ...                           ...          ...              ...          ...
# Oct-18    social                -            -                -            -
#           conflict              -            -                -            -
#           env                   -            -                -            -
#           health                -            -                -            -
#           eco                   -            -                -            -
# Aug-18    social                -            -                -            -
#           conflict              -            -                -            -
#           env                   -            -                -            -
#           health                -            -                -            -
#           eco                   -            -                -            -
# Apr-18    social                -            -                -            -
#           conflict              -            -                -            -
#           env                   -            -                -            -
#           health                -            -                -            -
#           eco                   -            -                -            -
# Sep-18    social                -            -                -            -
#           conflict              -            -                -            -
#           env                   -            -                -            -
#           health                -            -                -            -
#           eco                   -            -                -            -
# Jun-18    social                -            -                -            -
#           conflict              -            -                -            -
#           env                   -            -                -            -
#           health                -            -                -            -
#           eco                   -            -                -            -
# full_year social                -            -                -            -
#           conflict              -            -                -            -
#           env                   -            -                -            -
#           health                -            -                -            -
#           eco                   -            -                -            -
#
#                    wgntv.com wtop.com
# Month     Theme
# Jan-18    social           -        -
#           conflict         -        -
#           env              -        -
#           health           -        -
#           eco              -        -
# Jul-18    social           -        -
#           conflict         -        -
#           env              -        -
#           health           -        -
#           eco              -        -
# Mar-18    social           -        -
#           conflict         -        -
#           env              -        -
#           health           -        -
#           eco              -        -
# Nov-18    social           -        -
#           conflict         -        -
#           env              -        -
#           health           -        -
#           eco              -        -
# May-18    social           -        -
#           conflict         -        -
#           env              -        -
#           health           -        -
#           eco              -        -
# Feb-18    social           -        -
#           conflict         -        -
#           env              -        -
#           health           -        -
#           eco              -        -
# ...                      ...      ...
# Oct-18    social           -        -
#           conflict         -        -
#           env              -        -
#           health           -        -
#           eco              -        -
# Aug-18    social           -        -
#           conflict         -        -
#           env              -        -
#           health           -        -
#           eco              -        -
# Apr-18    social           -        -
#           conflict         -        -
#           env              -        -
#           health           -        -
#           eco              -        -
# Sep-18    social           -        -
#           conflict         -        -
#           env              -        -
#           health           -        -
#           eco              -        -
# Jun-18    social           -        -
#           conflict         -        -
#           env              -        -
#           health           -        -
#           eco              -        -
# full_year social           -        -
#           conflict         -        -
#           env              -        -
#           health           -        -
#           eco              -        -
#
# [65 rows x 50 columns]

# %%
for theme in tqdm_notebook(THEME_LIST[1:]):
    theme_df = full_df.loc[ind[theme]]
    for m in MONTH_LIST:
        if m == 'full_year':
            df = theme_df.copy()
        else:
            df = theme_df[theme_df.month==m].copy()
                
        count_histograms.loc[m,theme] = df.groupby("MentionSourceName").size()
        tone_histograms.loc[m,theme] = df.groupby("MentionSourceName").mean()["avg_tone"]
# Out:
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))

# %%
tone_histograms['abc13.com']
# Out:
# Month      Theme
# Jan-18     social     -3.28837
#            conflict   -3.32274
#            env          -3.356
#            health     -3.29691
#            eco        -3.16733
# Jul-18     social     -3.27027
#            conflict   -3.28681
#            env        -3.23819
#            health     -3.27341
#            eco        -3.21248
# Mar-18     social     -3.06384
#            conflict   -3.04496
#            env        -3.12063
#            health     -3.03101
#            eco        -2.93312
# Nov-18     social     -3.29792
#            conflict   -3.29746
#            env        -3.34633
#            health     -3.31227
#            eco        -3.19119
# May-18     social     -3.44319
#            conflict   -3.42491
#            env        -3.46296
#            health     -3.43676
#            eco        -3.42048
# Feb-18     social     -3.64064
#            conflict   -3.59594
#            env        -3.61532
#            health     -3.56332
#            eco        -3.62453
#                         ...
# Oct-18     social     -3.62106
#            conflict    -3.5982
#            env        -3.49371
#            health     -3.55624
#            eco        -3.55002
# Aug-18     social     -3.62106
#            conflict   -3.62113
#            env         -3.6039
#            health     -3.65952
#            eco        -3.56082
# Apr-18     social     -3.04607
#            conflict   -3.06657
#            env        -3.00838
#            health     -3.03839
#            eco        -3.13404
# Sep-18     social     -3.54582
#            conflict    -3.5464
#            env        -3.57373
#            health     -3.59789
#            eco        -3.53096
# Jun-18     social     -2.81603
#            conflict    -2.8159
#            env        -2.83742
#            health     -2.81062
#            eco         -2.8442
# full_year  social     -3.32782
#            conflict   -3.32377
#            env        -3.32795
#            health     -3.31956
#            eco        -3.29385
# Name: abc13.com, Length: 65, dtype: object

# %%
for m in MONTH_LIST:
    os.makedirs("../data/histograms/"+m)

# %%
for s in sources:
    for x,y in zip(count_histograms[s].unstack().iterrows(), tone_histograms[s].unstack().iterrows()):
        pd.concat([x[1],y[1]],axis=1).to_csv("../data/histograms/"+x[0]+"/"+s+".csv", header=["count", "avg_tone"])

# %%
for s in sources:
    for r in tone_histograms[s].unstack().iterrows():
        r[1].to_csv("../data/histograms/"+s+"/"+r[0]+"/tone.csv", header=["Tone"])

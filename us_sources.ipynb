# %%
import pandas as pd
import json
import numpy as np
from tqdm import tqdm_notebook
import matplotlib.pyplot as plt
import pickle

# %%
df = pd.read_csv("data/mentions-year-top100-us.gzip", compression='gzip')
df
# Out:
#           GLOBALEVENTID    MentionSourceName
# 0             727802116             wfla.com
# 1             753462663           news10.com
# 2             776577088    abcactionnews.com
# 3             764175820       nbcnewyork.com
# 4             722603290    nbcwashington.com
# 5             757851077             kxan.com
# 6             788929854             kdvr.com
# 7             766869017           nbcdfw.com
# 8             778705342             wsvn.com
# 9             744063976            pix11.com
# 10            786016754            wgntv.com
# 11            744711391      nbcsandiego.com
# 12            784218926            kron4.com
# 13            775300394             kdvr.com
# 14            743844510             wxyz.com
# 15            804190113    abcactionnews.com
# 16            804217426           nbcdfw.com
# 17            756579419  chicagobusiness.com
# 18            714283666             ktla.com
# 19            714278527             kdvr.com
# 20            714234946       nbcnewyork.com
# 21            796028569      nbcsandiego.com
# 22            796168723    abcactionnews.com
# 23            796204494             whdh.com
# 24            796217094     fox5sandiego.com
# 25            796028561             ktla.com
# 26            796049700             whdh.com
# 27            796142905             wxyz.com
# 28            796160837             wsvn.com
# 29            784700218            wgntv.com
# ...                 ...                  ...
# 10998910      789642949   huffingtonpost.com
# 10998911      789642951   huffingtonpost.com
# 10998912      708586758   huffingtonpost.com
# 10998913      709780081   huffingtonpost.com
# 10998914      758731692   huffingtonpost.com
# 10998915      737499814   huffingtonpost.com
# 10998916      766992513   huffingtonpost.com
# 10998917      734374756   huffingtonpost.com
# 10998918      720750378   huffingtonpost.com
# 10998919      721052313   huffingtonpost.com
# 10998920      721116998   huffingtonpost.com
# 10998921      722231305   huffingtonpost.com
# 10998922      740001492   huffingtonpost.com
# 10998923      756913596   huffingtonpost.com
# 10998924      756637653   huffingtonpost.com
# 10998925      757091815   huffingtonpost.com
# 10998926      709516492   huffingtonpost.com
# 10998927      799688483   huffingtonpost.com
# 10998928      708811103   huffingtonpost.com
# 10998929      708624855   huffingtonpost.com
# 10998930      727588468   huffingtonpost.com
# 10998931      725586855   huffingtonpost.com
# 10998932      714636013   huffingtonpost.com
# 10998933      714624045   huffingtonpost.com
# 10998934      788711722   huffingtonpost.com
# 10998935      725048390   huffingtonpost.com
# 10998936      765474198   huffingtonpost.com
# 10998937      802754944   huffingtonpost.com
# 10998938      795775220   huffingtonpost.com
# 10998939      710594480   huffingtonpost.com
#
# [10998940 rows x 2 columns]

# %%
# distribution of nb of articles by sources
nb_articles = df.groupby("MentionSourceName").size()
nb_articles.describe()
# Out:
# count    8.300000e+01
# mean     1.325173e+05
# std      3.471676e+05
# min      3.700000e+01
# 25%      1.074450e+04
# 50%      2.644700e+04
# 75%      1.212535e+05
# max      2.415235e+06
# dtype: float64

# %%
nb_articles.hist(bins=100)
plt.show()

# %%
nb_articles.sort_values(ascending=False)
# Out:
# MentionSourceName
# reuters.com                 2415235
# yahoo.com                   1983114
# nbcnews.com                  440119
# seattletimes.com             425986
# miamiherald.com              394610
# foxnews.com                  388529
# stltoday.com                 384745
# seattlepi.com                327661
# nydailynews.com              302527
# nytimes.com                  302338
# chicagotribune.com           244564
# latimes.com                  208850
# wtop.com                     202490
# bostonherald.com             195113
# newsweek.com                 177229
# newsmax.com                  172031
# philly.com                   157981
# breitbart.com                154986
# politico.com                 153545
# usatoday.com                 151275
# huffingtonpost.com           122001
# cbsnews.com                  120506
# nypost.com                   116184
# dailyherald.com               94158
# abc13.com                     93478
# npr.org                       91583
# abc7news.com                  85118
# newsday.com                   84765
# boston.com                    60201
# mercurynews.com               57016
#                              ...
# nbcsandiego.com               18627
# nbcphiladelphia.com           18567
# news10.com                    18544
# autonews.com                  15798
# observer.com                  15408
# wsvn.com                      13356
# nbcmiami.com                  13057
# chicagobusiness.com           11385
# amny.com                      10746
# phillyvoice.com               10743
# westword.com                   7723
# minnpost.com                   6560
# miaminewtimes.com              6013
# gothamist.com                  5620
# metrotimes.com                 5421
# phoenixnewtimes.com            4988
# villagevoice.com               3999
# riverfronttimes.com            3686
# texasobserver.org              3561
# nysun.com                      2429
# laweekly.com                   1964
# houstonpress.com               1805
# theonion.com                   1558
# billypenn.com                  1228
# chicagoreader.com               941
# laobserved.com                  312
# atlantaintownpaper.com          311
# miamitodaynews.com              142
# pridepublishinggroup.com         60
# laindependent.com                37
# Length: 83, dtype: int64

# %%
sources = set(df.MentionSourceName)

# %%
with open("data/sources_from_top_in_gdelt.pkl", "wb") as f:
    pickle.dump(sources, f)

# %%
with open("data/top50_US_sources.pkl", "rb") as f:
    sources = set(pickle.load(f))

# %%
nb_articles[sources].sort_values(ascending=False)
# Out:
# MentionSourceName
# nbcnews.com            440119
# seattletimes.com       425986
# miamiherald.com        394610
# foxnews.com            388529
# stltoday.com           384745
# seattlepi.com          327661
# nydailynews.com        302527
# nytimes.com            302338
# chicagotribune.com     244564
# latimes.com            208850
# wtop.com               202490
# bostonherald.com       195113
# newsweek.com           177229
# newsmax.com            172031
# philly.com             157981
# breitbart.com          154986
# politico.com           153545
# usatoday.com           151275
# huffingtonpost.com     122001
# cbsnews.com            120506
# nypost.com             116184
# abc13.com               93478
# npr.org                 91583
# abc7news.com            85118
# newsday.com             84765
# boston.com              60201
# mercurynews.com         57016
# ktla.com                50588
# denverpost.com          48105
# fox2now.com             42996
# kron4.com               33408
# wgntv.com               31311
# kdvr.com                27077
# nbcwashington.com       26447
# kxan.com                26407
# nbcnewyork.com          24061
# nbclosangeles.com       22044
# nbcchicago.com          19825
# twincities.com          19061
# nbcsandiego.com         18627
# nbcphiladelphia.com     18567
# autonews.com            15798
# observer.com            15408
# phillyvoice.com         10743
# westword.com             7723
# miaminewtimes.com        6013
# gothamist.com            5620
# villagevoice.com         3999
# laweekly.com             1964
# theonion.com             1558
# dtype: int64

# %%
nodes = []
edges = []
new_sources = sources

for source1 in tqdm_notebook(sources):
    nodes.append({ 'id' : source1, 'size' : int(nb_articles[source1])}) 
    events1 = set(df[df.MentionSourceName==source1].GLOBALEVENTID)
    new_sources = new_sources - {source1}
    
    for source2 in new_sources:
        if source1==source2:
            continue
            
        events2 = set(df[df.MentionSourceName==source2].GLOBALEVENTID)
        w = len(events1 & events2)
        
        edges.append({'source': source1, 'target': source2, 'weight': w})
# Out:
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))

# %%
nodes
# Out:
# [{'id': 'mercurynews.com', 'size': 57016},
#  {'id': 'nydailynews.com', 'size': 302527},
#  {'id': 'nbcnewyork.com', 'size': 24061},
#  {'id': 'kdvr.com', 'size': 27077},
#  {'id': 'newsmax.com', 'size': 172031},
#  {'id': 'miamiherald.com', 'size': 394610},
#  {'id': 'politico.com', 'size': 153545},
#  {'id': 'autonews.com', 'size': 15798},
#  {'id': 'foxnews.com', 'size': 388529},
#  {'id': 'npr.org', 'size': 91583},
#  {'id': 'westword.com', 'size': 7723},
#  {'id': 'boston.com', 'size': 60201},
#  {'id': 'philly.com', 'size': 157981},
#  {'id': 'bostonherald.com', 'size': 195113},
#  {'id': 'abc7news.com', 'size': 85118},
#  {'id': 'nbcphiladelphia.com', 'size': 18567},
#  {'id': 'observer.com', 'size': 15408},
#  {'id': 'twincities.com', 'size': 19061},
#  {'id': 'kxan.com', 'size': 26407},
#  {'id': 'newsweek.com', 'size': 177229},
#  {'id': 'seattlepi.com', 'size': 327661},
#  {'id': 'nbcwashington.com', 'size': 26447},
#  {'id': 'phillyvoice.com', 'size': 10743},
#  {'id': 'stltoday.com', 'size': 384745},
#  {'id': 'newsday.com', 'size': 84765},
#  {'id': 'nypost.com', 'size': 116184},
#  {'id': 'cbsnews.com', 'size': 120506},
#  {'id': 'wtop.com', 'size': 202490},
#  {'id': 'gothamist.com', 'size': 5620},
#  {'id': 'fox2now.com', 'size': 42996},
#  {'id': 'laweekly.com', 'size': 1964},
#  {'id': 'nbcsandiego.com', 'size': 18627},
#  {'id': 'villagevoice.com', 'size': 3999},
#  {'id': 'breitbart.com', 'size': 154986},
#  {'id': 'nytimes.com', 'size': 302338},
#  {'id': 'latimes.com', 'size': 208850},
#  {'id': 'usatoday.com', 'size': 151275},
#  {'id': 'nbcchicago.com', 'size': 19825},
#  {'id': 'abc13.com', 'size': 93478},
#  {'id': 'theonion.com', 'size': 1558},
#  {'id': 'wgntv.com', 'size': 31311},
#  {'id': 'miaminewtimes.com', 'size': 6013},
#  {'id': 'denverpost.com', 'size': 48105},
#  {'id': 'chicagotribune.com', 'size': 244564},
#  {'id': 'ktla.com', 'size': 50588},
#  {'id': 'kron4.com', 'size': 33408},
#  {'id': 'seattletimes.com', 'size': 425986},
#  {'id': 'nbclosangeles.com', 'size': 22044},
#  {'id': 'huffingtonpost.com', 'size': 122001},
#  {'id': 'nbcnews.com', 'size': 440119}]

# %%
len(edges)
# Out:
# 1225

# %%
threshold = 0
filtered_edges = [ e for e in edges if e['weight'] > threshold ]

# %%
len(filtered_edges)
# Out:
# 1221

# %%
network = {'nodes': nodes, 'edges': filtered_edges}

# %%
with open("data/top"+str(len(nodes))+"-US-year-"+str(threshold)+".json", "w") as f:
    json.dump(network, f, indent=2)
